# %%
import pandas as pd
from config.path_config import lakefs_s3_path
import os

# %%
df = pd.read_csv(r'C:\dsi321_2025\data\tweet_data.csv')
display(df)
# Out:
#       category                   tag          username  \
# 0   ธรรมศาสตร์  #ธรรมศาสตร์ช้างเผือก      @somuensojai
# 1   ธรรมศาสตร์  #ธรรมศาสตร์ช้างเผือก        @DEXCEM212
# 2   ธรรมศาสตร์  #ธรรมศาสตร์ช้างเผือก    @jaeminjenfffy
# 3   ธรรมศาสตร์  #ธรรมศาสตร์ช้างเผือก       @mankheuthe
# 4   ธรรมศาสตร์  #ธรรมศาสตร์ช้างเผือก     @green_thai04
# 5   ธรรมศาสตร์  #ธรรมศาสตร์ช้างเผือก        @tatty07_5
# 6   ธรรมศาสตร์  #ธรรมศาสตร์ช้างเผือก    @Sundayyyyyy18
# 7   ธรรมศาสตร์  #ธรรมศาสตร์ช้างเผือก         @102yhnml
# 8   ธรรมศาสตร์  #ธรรมศาสตร์ช้างเผือก   @MasterJang4856
# 9   ธรรมศาสตร์  #ธรรมศาสตร์ช้างเผือก       @mellow3to3
# 10  ธรรมศาสตร์  #ธรรมศาสตร์ช้างเผือก        @20_4_2020
# 11  ธรรมศาสตร์                 #TCAS          @jacazry
# 12  ธรรมศาสตร์                 #TCAS       @taehtaehhh
# 13  ธรรมศาสตร์                 #TCAS        @babobanie
# 14  ธรรมศาสตร์                 #TCAS        @ahcin_mii
# 15  ธรรมศาสตร์                 #TCAS         @hipstect
# 16  ธรรมศาสตร์                 #TCAS         @JunPapol
# 17  ธรรมศาสตร์                 #TCAS   @studydiary_png
# 18  ธรรมศาสตร์                 #TCAS    @IELTS_with_me
# 19  ธรรมศาสตร์                 #TCAS   @shupn_dropfile
# 20  ธรรมศาสตร์               #รับตรง      @wetalkinter
# 21  ธรรมศาสตร์                #ทีมมธ   @studywteacherB
# 22  ธรรมศาสตร์                #ทีมมธ          @Gsijsj4
# 23  ธรรมศาสตร์                #ทีมมธ          @rosyx__
# 24  ธรรมศาสตร์                #ทีมมธ       @No05149699
# 25  ธรรมศาสตร์                #ทีมมธ        @moremar03
# 26  ธรรมศาสตร์                   #มธ       @ingo642244
# 27  ธรรมศาสตร์                   #มธ       @468Shackky
# 28  ธรรมศาสตร์                   #มธ      @Dxnnyyxewjj
# 29  ธรรมศาสตร์                   #มธ       @No05149699
# 30  ธรรมศาสตร์                   #มธ     @dynamite2255
# 31  ธรรมศาสตร์                   #มธ     @moominniniin
# 32  ธรรมศาสตร์                   #มธ  @summersunnysoon
# 33  ธรรมศาสตร์                   #มธ         @koookg69
# 34  ธรรมศาสตร์                   #มธ     @winissocute1
# 35  ธรรมศาสตร์                   #มธ   @detectivekatia
# 36  ธรรมศาสตร์                #dek70       @forwardqqq
# 37  ธรรมศาสตร์                #dek70       @forwardqqq
# 38  ธรรมศาสตร์                #dek70       @forwardqqq
# 39  ธรรมศาสตร์                #dek70       @forwardqqq
# 40  ธรรมศาสตร์                #dek70       @forwardqqq
# 41  ธรรมศาสตร์                #dek70       @forwardqqq
# 42  ธรรมศาสตร์                #dek70     @theanflowery
# 43  ธรรมศาสตร์                #มอท่อ         @WdiWngkh
# 44  ธรรมศาสตร์                #มอท่อ        @ttaattaac
# 45  ธรรมศาสตร์                #มอท่อ        @thelonerp
# 35  2025-05-12 02:02:26  2025      5   11
# 36  2025-05-12 02:02:40  2025      5   11
# 37  2025-05-12 02:02:40  2025      5   11
# 38  2025-05-12 02:02:40  2025      5   11
# 39  2025-05-12 02:02:40  2025      5   11
# 40  2025-05-12 02:02:40  2025      5   11
# 41  2025-05-12 02:02:40  2025      5   11
# 42  2025-05-12 02:03:04  2025      5   11
# 43  2025-05-12 02:03:20  2025      2   28
# 44  2025-05-12 02:03:20  2025      2    1
# 45  2025-05-12 02:03:20  2024      7    8
# 46  2025-05-12 02:03:20  2024      5   20
# 47  2025-05-12 02:03:20  2024      3    7
# 48  2025-05-12 02:03:20  2023     10   21
# 49  2025-05-12 02:03:20  2023      9   21
# 50  2025-05-12 02:03:20  2023      5   20
# 51  2025-05-12 02:03:20  2023      3   22
# 52  2025-05-12 02:03:32  2025      5   11
# 53  2025-05-12 02:03:32  2025      5   11
# 54  2025-05-12 02:03:32  2025      5   11
# 55  2025-05-12 02:03:32  2025      5   11
# 56  2025-05-12 02:03:32  2025      5   11
# 57  2025-05-12 02:03:32  2025      5   11
# 58  2025-05-12 02:03:52  2025      5   11

# %%
lakefs_endpoint = "http://localhost:8001/"
storage_options = {
    "key": os.getenv("ACCESS_KEY"),
    "secret": os.getenv("SECRET_KEY"),
    "client_kwargs": {
        "endpoint_url": lakefs_endpoint
    }
}
repo_name = "tweets-repo"
branch_name = "main"
path = "tweets.parquet"
lakefs_s3_path = f"local://{repo_name}/{branch_name}/{path}"
data = pd.read_parquet(
    lakefs_s3_path,
    storage_options=storage_options,
    engine='pyarrow',
)

data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 13
#      11 path = "tweets.parquet"
#      12 lakefs_s3_path = f"local://{repo_name}/{branch_name}/{path}"
# ---> 13 data = pd.read_parquet(
#      14     lakefs_s3_path,
#      15     storage_options=storage_options,
#      16     engine='pyarrow',
#      17 )
#      19 data.head()
#
# File c:\dsi321_2025\.venv\Lib\site-packages\pandas\io\parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# File c:\dsi321_2025\.venv\Lib\site-packages\pandas\io\parquet.py:274, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     267 path_or_handle, handles, filesystem = _get_path_or_handle(
#     268     path,
#     269     filesystem,
#     270     storage_options=storage_options,
#     271     mode="rb",
#     272 )
#     273 try:
# --> 274     pa_table = self.api.parquet.read_table(
#     275         path_or_handle,
#     276         columns=columns,
#     277         filesystem=filesystem,
#     278         filters=filters,
#     279         **kwargs,
#     280     )
#     281     result = pa_table.to_pandas(**to_pandas_kwargs)
#     283     if manager == "array":
#
# File c:\dsi321_2025\.venv\Lib\site-packages\pyarrow\parquet\core.py:1774, in read_table(source, columns, use_threads, schema, use_pandas_metadata, read_dictionary, memory_map, buffer_size, partitioning, filesystem, filters, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, page_checksum_verification)
#    1764 def read_table(source, *, columns=None, use_threads=True,
#    1765                schema=None, use_pandas_metadata=False, read_dictionary=None,
#    1766                memory_map=False, buffer_size=0, partitioning="hive",
#    (...)   1770                thrift_container_size_limit=None,
#    1771                page_checksum_verification=False):
#    1773     try:
# -> 1774         dataset = ParquetDataset(
#    1775             source,
#    1776             schema=schema,
#    1777             filesystem=filesystem,
#    1778             partitioning=partitioning,
#    1779             memory_map=memory_map,
#    1780             read_dictionary=read_dictionary,
#    1781             buffer_size=buffer_size,
#    1782             filters=filters,
#    1783             ignore_prefixes=ignore_prefixes,
#    1784             pre_buffer=pre_buffer,
#    1785             coerce_int96_timestamp_unit=coerce_int96_timestamp_unit,
#    1786             decryption_properties=decryption_properties,
#    1787             thrift_string_size_limit=thrift_string_size_limit,
#    1788             thrift_container_size_limit=thrift_container_size_limit,
#    1789             page_checksum_verification=page_checksum_verification,
#    1790         )
#    1791     except ImportError:
#    1792         # fall back on ParquetFile for simple cases when pyarrow.dataset
#    1793         # module is not available
#    1794         if filters is not None:
#
# File c:\dsi321_2025\.venv\Lib\site-packages\pyarrow\parquet\core.py:1361, in ParquetDataset.__init__(self, path_or_paths, filesystem, schema, filters, read_dictionary, memory_map, buffer_size, partitioning, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, page_checksum_verification)
#    1357 if partitioning == "hive":
#    1358     partitioning = ds.HivePartitioning.discover(
#    1359         infer_dictionary=True)
# -> 1361 self._dataset = ds.dataset(path_or_paths, filesystem=filesystem,
#    1362                            schema=schema, format=parquet_format,
#    1363                            partitioning=partitioning,
#    1364                            ignore_prefixes=ignore_prefixes)
#
# File c:\dsi321_2025\.venv\Lib\site-packages\pyarrow\dataset.py:794, in dataset(source, schema, format, filesystem, partitioning, partition_base_dir, exclude_invalid_files, ignore_prefixes)
#     783 kwargs = dict(
#     784     schema=schema,
#     785     filesystem=filesystem,
#    (...)    790     selector_ignore_prefixes=ignore_prefixes
#     791 )
#     793 if _is_path_like(source):
# --> 794     return _filesystem_dataset(source, **kwargs)
#     795 elif isinstance(source, (tuple, list)):
#     796     if all(_is_path_like(elem) or isinstance(elem, FileInfo) for elem in source):
#
# File c:\dsi321_2025\.venv\Lib\site-packages\pyarrow\dataset.py:476, in _filesystem_dataset(source, schema, filesystem, partitioning, format, partition_base_dir, exclude_invalid_files, selector_ignore_prefixes)
#     474         fs, paths_or_selector = _ensure_multiple_sources(source, filesystem)
#     475 else:
# --> 476     fs, paths_or_selector = _ensure_single_source(source, filesystem)
#     478 options = FileSystemFactoryOptions(
#     479     partitioning=partitioning,
#     480     partition_base_dir=partition_base_dir,
#     481     exclude_invalid_files=exclude_invalid_files,
#     482     selector_ignore_prefixes=selector_ignore_prefixes
#     483 )
#     484 factory = FileSystemDatasetFactory(fs, paths_or_selector, format, options)
#
# File c:\dsi321_2025\.venv\Lib\site-packages\pyarrow\dataset.py:441, in _ensure_single_source(path, filesystem)
#     439     paths_or_selector = [path]
#     440 else:
# --> 441     raise FileNotFoundError(path)
#     443 return filesystem, paths_or_selector
#
# FileNotFoundError: c:/dsi321_2025/test/tweets-repo/main/tweets.parquet
